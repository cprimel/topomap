# %%
using TopoMap
using Plots, Distributions, MLDatasets, Random 
pyplot();
# Out:
# ** (process:35564): WARNING **: 22:08:16.198: Failed to load shared library 'libpango-1.0.so.0' referenced by the typelib: /usr/lib/libpango-1.0.so.0: undefined symbol: hb_ot_layout_get_horizontal_baseline_tag_for_script

# %%
data = rand(Normal(0), (3, 266))
labels = repeat([1], 266)
data = hcat(data, rand(Normal(5), (3,266)))
append!(labels, repeat([2],266))
data = hcat(data, rand(Normal(10), (3,267)))
append!(labels, repeat([3],267))
scatter(data[1,:], data[2,:], data[3,:], group=labels)

# %%
#@time tm, _ = TopoMap.project(data, 10 ,true);
@time tm = TopoMap.project(data, 10 ,true);
# Out:
# Computing EMST...
# --> ngroups: 799
# --> ngroups: 226
# --> ngroups: 52
# --> ngroups: 11
# --> ngroups: 3
# Placing points...
#   0.207372 seconds (2.32 M allocations: 66.687 MiB, 14.01% gc time)

# %%
scatter(tm[1,:], tm[2,:],group=labels, title = "Projection")

# %%
#Iris.download(; i_accept_the_terms_of_use=true);
iris_features = Iris.features();
iris_labels = Iris.labels();

# %%
#@time tm_iris, steps = TopoMap.project(iris_features, 10, true);
@time tm_iris = TopoMap.project(iris_features, 10, true);
# Out:
# Computing EMST...
# --> ngroups: 150
# --> ngroups: 42
# --> ngroups: 8
# --> ngroups: 3
# Placing points...
#   0.005281 seconds (12.47 k allocations: 1.561 MiB)

# %%
scatter(tm_iris[1,:], tm_iris[2,:], group=iris_labels,title = "2D Projection of Iris Dataset")

# %% [markdown]
# ## Generate .gif

# %%
#xMax = maximum(tm_iris[1,:])
#xMin = -xMax
#yMax = maximum(tm_iris[2,:])
#yMin =-yMax
#anim = @animate for i in 1:length(steps)
#    step = steps[i]
#    res = Array{Float64,2}(undef, 2, length(step))
#    for i in eachindex(step)
#        res[1, i] = step[i].p.x
#        res[2, i] = step[i].p.y
#    end
#    scatter(res[1,:], res[2,:],group=iris_labels,xlim=(xMin,xMax), ylim=(yMin, yMax))
#end

# %%
#gif(anim, fps=5)

# %% [markdown]
# ## 3d projection of Iris data

# %%
#@time tm_iris_3d, steps = TopoMap.project(iris_features, 3, 10, true);

# %%
#scatter(tm_iris_3d[1,:], tm_iris_3d[2,:], tm_iris_3d[3,:],group=iris_labels,title = "3D Projection of Iris Dataset")
